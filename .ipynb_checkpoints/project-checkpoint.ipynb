# %%
using LinearAlgebra
using Plots
using DelimitedFiles
using LightGraphs
using StatsBase
using Distributions
using GraphPlot

# %% [markdown]
# # Part I: Network

# %%
# Create a network that have 98 nodes, represents the "spaces" of a shopping mall
G = Graph(98)
# A public space connecting to all cluster and offsite
node_labels=["public Space"];

# %%
# node 2-7 will be restaurant cluster, each is connect to the public space
for i in 2:7
    add_edge!(G, 1, i)
end

# node 32-39 will be retail store cluster, each is connect to the public space
for i in 32:39
    add_edge!(G,1,i)
end

# node 80 will be movie theater cluster, connect to the public space
add_edge!(G,1,80)

#node 93 will be gym cluster, 
add_edge!(G,1,93)

#node 98 will be offsite from shopping mall, connect to the public space
add_edge!(G,1,98)
# Out:
# true

# %%
# for each restaurant cluster there will be edges connection to 4 different restaurants 
for i in 1:6
    for j in 1:4
        add_edge!(G, i+1, 4*i-4+j+7)
    end
end

# for each retail store cluster there will be edges connection to 5 different retail stores 
for i in 1:8
    for j in 1:5
        add_edge!(G, i+31, 5*i-5+j+39)
    end
end

# movie theater cluster will have edges to connect to 12 other show rooms
for i in 1:1
    for j in 1:12
        add_edge!(G, i+79, 12*i-12+j+80)
    end
end

# gym cluster will have edges to connect to 4 gym rooms
for i in 1:1
    for j in 1:4
        add_edge!(G, i+92, 4*i-4+j+93)
    end
end

# %%
# Adding appropriate label for each nodes
for i in 2:7
     push!(node_labels,"restaurant cluster")
end

for i in 8:31
    push!(node_labels, "restaurant $(i-7)")
end

for i in 32:39
    push!(node_labels, "retail store cluster")
end

for i in 40:79
    push!(node_labels, "retail store $(i-39)")
end

push!(node_labels, "cinema cluster")
for i in 81:92
    push!(node_labels, "cinema room $(i-80)")
end

push!(node_labels, "gym cluster")

for i in 94:97
    push!(node_labels, "gym room $(i-93)")
end

push!(node_labels, "Home");

# %%
# Plot the network
gplot(G, nodelabel=node_labels, NODELABELSIZE=1)
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.013912093473335732cx, -0.06692442171155881cy), (0.06373218508781313cx, -0.5206858361112665cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.00045895198188612707cx, -0.018945065406071836cy), (-0.2319347322366951cx, 0.4780476080767703cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.02384274616318504cx, -0.06365721533778601cy), (0.2396549454994238cx, -0.43510027921625294cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.013324533406082924cx, -0.048023157666656914cy), (-0.4128053085335966cx, -0.14922458010011727cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.011918405423105984cx, -0.03155845379855306cy), (-0.4101714212435358cx, 0.14557640334298816cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.0034236626862779312cx, -0.06244159460399722cy), (-0.24734275888103127cx, -0.40741957152766783cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.014006605621408829cx, -0.03967647855868019cy), (-0.6535102743867771cx, 0.014837955408414937cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.035170426998154654cx, -0.04963554540653161cy), (0.5312034597666319cx, -0.2110400673084419cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.03371531335816978cx, -0.030471119582039664cy), (0.5280886838968284cx, 0.21826395897443632cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.0363351184341809cx, -0.03988121674330973cy), (0.6443790031133452cx, 0.0069730705491479065cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.09287135314190278cx, 0.6631836516805973cy), (0.11464131993805468cx, 0.6354722886690316cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.07793109668869157cx, 0.7082874893725511cy), (0.0844092815301415cx, 0.9558340167937817cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.07580748350624587cx, 0.7082537220957366cy), (0.06602683481603912cx, 0.8768052925161072cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.05562473057146637cx, 0.6960507121577929cy), (-0.050840470188542916cx, 0.7600329583354614cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.09436439931961171cx, 0.7016313400401565cy), (0.2084367813767123cx, 0.8256806656996515cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.06252012058962568cx, 0.7035406878431254cy), (-0.046179724645560014cx, 0.8545997424354306cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.43803479307863336cx, 0.3657351991959045cy), (-0.6210471432946248cx, 0.46247946431549797cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.4321880351226587cx, 0.3730688521542641 ...

# %% [markdown]
# # Part II: Simulation

# %%
# Constructor for the agents in the simulation
mutable struct Person
    isInfected
    isEmployee
    hadMeal
    exposed
    isBackHome
    isWatchingMovie
    #An array that contains the location where the agent will be at (From 10am to 9pm)
    schedule 
    #An array that contains the true/false for each intervention(by index) that agent follows
    #1.Social distance, 2.mask, 3.temperature measurement, limit the number of people in a place
    intervention     
    
end

# %%
#= 
purpose: Generate a schedule for agents who are customers
parameter: person, Person(mutable structure)
produce: person, Person(mutable structure) with a schedule 
=#
function generateScheduleCustomer(person,temperature)
    if temperature && person.exposed>=14
        person.schedule=fill(98,12)
        return
    end
    # Set schedule back to empty
    person.schedule=[]
    # The process will repeat for 12 times
    for i in 10:21
        # If the person is still at the shopping mall
        if(!person.isBackHome)
            # If the person is not an employee
            if(!person.isEmployee)
                #If the person is already watching a movie then they will stay at same location for another hour
                if(person.isWatchingMovie)
                    push!(person.schedule,person.schedule[length(person.schedule)])
                    # After two hours, person has finish watching the movie
                    person.isWatchingMovie=false
                    continue
                end
                #Person will pick a restaurant for food if they haven't eat after 17:00
                if(i>17 && !person.hadMeal)
                    push!(person.schedule, rand(40:79))
                    person.hadMeal=true
                end
                # Choose a place to go to 
                place=rand(1:98)
                #If the person already had a meal they will not eat another meal
                if (person.hadMeal)
                        place=rand(1:98)
                        while(place >= 8 && place <= 31)
                            place=rand(1:98)
                        end
                end
                # If the place is a restaurant, person will had a meal
                if(place >= 8 && place <= 31)
                        person.hadMeal=true
                end
                # If the place is a showing room, then the person will be watching movie
                if(place >= 81 && place <= 92)
                    person.isWatchingMovie=true
                end
                # Add the location to person's schedule
                push!(person.schedule,place)
            end
        else
            # If the person is at home they will stay home
            push!(person.schedule,98)
        end
    end
end
# Out:
# generateScheduleCustomer (generic function with 1 method)

# %%
#=
purpose: Generate a schedule for agents who are employees
parameter: person, Person(mutable structure)
produce: person, Person(mutable structure) with a schedule  
=#
function generateScheduleEmployee(person,temperature)
    if temperature && person.exposed>=14
        person.schedule=fill(98,12)
        return
    end
    # Assign work location
    workposition=rand(1:97)
    # Assign start time for work
    startingTime = rand(10:14)
    #work hour set to 0
    workhour=0
    #Set schedule to be empty
    person.schedule=[]
    
    # Before working hour, person will not be in the mall
    if(startingTime>10)
        for i in 10:startingTime-1
            push!(person.schedule, 98)
        end
    end
    # When person start working
    for i in startingTime:21
        # If they've work for 7 hours then they will go home
        if workhour == 7
            push!(person.schedule, 98)
        else
            # Each time slot have 10% chance to be the person's free time
            freetime=rand(1:10)
            if freetime==10 && !person.hadMeal
                # person will pick a resturant to eat during their free time, if they haven't had their free time
                push!(person.schedule, rand(8:31))
                person.hadMeal=true
            else
                # person will stay in their workposition during their work hour
                push!(person.schedule, workposition)
                workhour+=1
            end
        end
    end
end
# Out:
# generateScheduleEmployee (generic function with 1 method)

# %%
#=
purpose: Generate e number of employee and c number of customers
parameter: e, an integer; c, an integer
produce: res, an array of Person, where the first e elements are "employee" and the rest are "customers"
=#
function generateEmployeeAndCustomer(e,c,p,arr)
    res=[]
    
    for i in 1:e
        #each employee have 0.05% chance of already been infected by COVID-19
        isInfected = rand(1:10000)<6
        #if they are already indected then we will assume they've been expose for more than 2 days, otherwise 
        #they've not been exposed
        expose = isInfected ? rand(1:15) : 1
        #creating the employee
        employee=Person(isInfected,true,false,expose,false,false,[],map((x)-> x ? p > rand(Float64) : false,arr))
        #add the employee into the result
        push!(res,employee)
    end
    for i in 1:c
        #each customer have 0.05% chance of already been infected by COVID-19
        isInfected = rand(1:10000)<6
        #if they are already indected then we will assume they've been expose for more than 2 days, otherwise 
        #they've not been exposed
        expose = isInfected ? rand(1:15) : 1
        #creating the customer
        customer=Person(isInfected,false,false,expose,false,false,[],map((x)-> x ? p > rand(Float64) : false,arr))
        #add the customer into the result
        push!(res,customer)
    end
    return res
end
# Out:
# generateEmployeeAndCustomer (generic function with 1 method)

# %%
#=
purpose: Generating schedule for agents
parameter: people, an array of Person; startpoint, an integer; endpoint an integer
produce: people, elements in people from index startpoint to endpoint have new schedule (void)
=#
function generateSchedule(people, startpoint, endpoint, temperature)
    #If the starting point is a employee, then from startpoint to endpoint will all be employee, 
    # otherwise all customer
    isEmployee=people[startpoint].isEmployee
    for i in startpoint:endpoint
        # If the they are all employee then generate employee schedule for them
        if isEmployee
            generateScheduleEmployee(people[i],temperature)
        else
        # Otherwise they are all customer and generate customer for them
            generateScheduleCustomer(people[i],temperature)
        end
    end
end
# Out:
# generateSchedule (generic function with 1 method)

# %%
#=
purpose: Generate a 2D array, where it contains the number of people at a location during a specific time of 
         the day
parameter: place, an 2D array; people, an array of Person; iteration, an integer
produce: place, an 2D array
=#
function location!(places,people, iteration)
    i = 1
    #Reset each array in the place to be empty
    for p in places
        places[i]=[]
        i+=1
    end
    i=1
    #For each Person in people 
    for p in people
        # Assign each person with an integer(based on its index in people) and place it into the 2D array
        push!(places[p.schedule[iteration]], i)
        i+=1
    end
end
# Out:
# location! (generic function with 1 method)

# %%
#=
purpose: Find the number of infected people, who is able to infect others, at each location
parameter: people, an array of Person, place, a 2D array of integer
produce: sum, an integer
=#
function hasCovid(people, place)
    # Set sum to be zero
    sum=0
    # For each integer in place
    for p in place
        # Get the coordinating person, and see if the person is infected and has been infected 
        # for more than 2 days 
        if people[p].isInfected==true && people[p].exposed>2
            sum+=1
        end
    end
    return sum
end
# Out:
# hasCovid (generic function with 1 method)

# %%
function generatePeople(emplyeeNum,customerNum,p,arr)
    #Generating emplyeeNum employee and customerNum customers
    people=generateEmployeeAndCustomer(emplyeeNum,customerNum,p, arr)
    #Generating the emplyeeNum employee schedules
    generateSchedule(people,1,emplyeeNum,arr[3])
    #Generating the customerNum customer schedules
    generateSchedule(people,emplyeeNum+1,emplyeeNum+customerNum,arr[3])
    return people
end
# Out:
# generatePeople (generic function with 1 method)

# %%
function simulate(emplyeeNum,customerNum,prob,interventions)
    riskmulti=fill(1,98)
    riskmulti[98]=0
    people=generatePeople(emplyeeNum,customerNum,prob,interventions)
    # people=generatePeople(emplyeeNum,customerNum,1,[false,false,false,false])
    totalInfection = []
    total = 0
    totalPeople = emplyeeNum
    daily=[]
    for x in 1:30
        d = 0
        for i in 1:12
            location!(places,people,i)
            k = 0
            for place in places
                k+=1
                infect = hasCovid(people, place)
                if interventions[2]
                    numOfInfecPeoWearingMask=length(filter((p)->people[p].isInfected && people[p].exposed>2 && people[p].intervention[2], place))
                    rate = riskmulti[k]*0.75*1.25*((infect-numOfInfecPeoWearingMask)+0.5*numOfInfecPeoWearingMask)/200
                    for p in place
                        people[p].isInfected = people[p].isInfected || (people[p].intervention[2] ? rand(Float64)<rate : 0.75*rand(Float64)<rate) 
                    end
                elseif interventions[1]
                        
                else
                    rate = riskmulti[k]*1.25*infect/200
                    for p in place
                        people[p].isInfected = people[p].isInfected || rand(Float64)<rate
                    end
                end

            end
        end
        for i in 1:emplyeeNum
            if people[i].isInfected
                people[i].exposed +=1
            end
        end
        totalPeople+=customerNum
        for i in emplyeeNum+1:emplyeeNum+customerNum
            if people[i].isInfected
                d+=1
            end
            isInfected = rand(1:10000)<6
            expose = isInfected ? rand(1:15) : 1
            people[i]=Person(isInfected,false,false,expose,false,false,[],map((x)-> x ? prob > rand(Float64) : false,interventions))
        end
        generateSchedule(people,emplyeeNum+1,emplyeeNum+customerNum,interventions[3])
#         generateSchedule(people,1001,10000,false)
        total+=d
        push!(totalInfection, total)
        push!(daily,d)
    end
    return [daily,totalInfection]
end
# Out:
# simulate (generic function with 1 method)

# %%
#Simulation variables:
# 1000 emplyees total
emplyeeNum=1000
# 9000 customer in the mall each day.
customerNum=9000

# ? length(filter((x)->x.isInfected, people))
#Setting the 2D array for places
places=[]
for i in 1:98
    push!(places, [])
end

# %%
res = simulate(emplyeeNum,customerNum,1,[false,false,false,false])
# Out:
# 2-element Array{Array{Any,1},1}:
#  [58, 34, 36, 18, 51, 56, 61, 93, 122, 148  …  781, 908, 990, 1003, 1090, 1245, 1259, 1431, 1561, 1624]
#  [58, 92, 128, 146, 197, 253, 314, 407, 529, 677  …  5543, 6451, 7441, 8444, 9534, 10779, 12038, 13469, 15030, 16654]

# %%
y = res[1]
x = 1:30
plot(x, y, title = "Daily infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("daily infection")

# %%
y = res[2]
x = 1:30
plot(x, y, title = "Overall infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("Overall infection")

# %% [markdown]
# # Facial mask

# %%
#Simulation variables:
# 1000 emplyees total
emplyeeNum=1000
# 9000 customer in the mall each day.
customerNum=9000

# ? length(filter((x)->x.isInfected, people))
#Setting the 2D array for places
places=[]
for i in 1:98
    push!(places, [])
end
res = simulate(emplyeeNum,customerNum,1,[false,true,false,false])
# Out:
# 2-element Array{Array{Any,1},1}:
#  [10, 17, 26, 33, 20, 13, 15, 15, 12, 18  …  35, 49, 30, 34, 35, 47, 47, 63, 79, 66]
#  [10, 27, 53, 86, 106, 119, 134, 149, 161, 179  …  496, 545, 575, 609, 644, 691, 738, 801, 880, 946]

# %%
y = res[1]
x = 1:30
plot(x, y, title = "Daily infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("daily infection")

# %%
y = res[2]
x = 1:30
plot(x, y, title = "Overall infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("Overall infection")

# %% [markdown]
# # Temperature

# %%
#Simulation variables:
# 1000 emplyees total
emplyeeNum=1000
# 9000 customer in the mall each day.
customerNum=9000

# ? length(filter((x)->x.isInfected, people))
#Setting the 2D array for places
places=[]
for i in 1:98
    push!(places, [])
end
res = simulate(emplyeeNum,customerNum,1,[false,false,true])
# Out:
# 2-element Array{Array{Any,1},1}:
#  [31, 65, 32, 69, 89, 117, 101, 179, 216, 324  …  1546, 1643, 1828, 1951, 2174, 2121, 2313, 2328, 2399, 2568]
#  [31, 96, 128, 197, 286, 403, 504, 683, 899, 1223  …  10980, 12623, 14451, 16402, 18576, 20697, 23010, 25338, 27737, 30305]

# %%
y = res[1]
x = 1:30
plot(x, y, title = "Daily infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("daily infection")

# %%
y = res[2]
x = 1:30
plot(x, y, title = "Overall infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("Overall infection")

# %% [markdown]
# # Limit number of people in the mall

# %%
#Simulation variables:
# 500 emplyees total
emplyeeNum=500
# 4500 customer in the mall each day.
customerNum=4500

# ? length(filter((x)->x.isInfected, people))
#Setting the 2D array for places
places=[]
for i in 1:98
    push!(places, [])
end
res = simulate(emplyeeNum,customerNum,1,[false,false,false])
# Out:
# 2-element Array{Array{Any,1},1}:
#  [6, 13, 19, 19, 6, 6, 12, 19, 23, 18  …  45, 80, 87, 112, 114, 112, 118, 124, 125, 134]
#  [6, 19, 38, 57, 63, 69, 81, 100, 123, 141  …  540, 620, 707, 819, 933, 1045, 1163, 1287, 1412, 1546]

# %%
y = res[1]
x = 1:30
plot(x, y, title = "Daily infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("daily infection")

# %%
y = res[2]
x = 1:30
plot(x, y, title = "Overall infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("Overall infection")

# %% [markdown]
# # Follow intervention 2,3,4

# %%
#Simulation variables:
# 500 emplyees total
emplyeeNum=500
# 4500 customer in the mall each day.
customerNum=4500

# ? length(filter((x)->x.isInfected, people))
#Setting the 2D array for places
places=[]
for i in 1:98
    push!(places, [])
end
res = simulate(emplyeeNum,customerNum,1,[false,true,true])
# Out:
# 2-element Array{Array{Any,1},1}:
#  [0, 1, 5, 1, 12, 8, 3, 3, 4, 4  …  12, 9, 9, 10, 10, 6, 14, 8, 7, 22]
#  [0, 1, 6, 7, 19, 27, 30, 33, 37, 41  …  114, 123, 132, 142, 152, 158, 172, 180, 187, 209]

# %%
y = res[1]
x = 1:30
plot(x, y, title = "Daily infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("daily infection")

# %%
y = res[2]
x = 1:30
plot(x, y, title = "Overall infection")
scatter!(x,y, label="point")
xlabel!("time")
ylabel!("Overall infection")

# %% [markdown]
# # Percentage of people following the intervention/Infection

# %% [markdown]
# # -Facial mask

# %%
overall = []
for p in 1:11
    #Simulation variables:
    # 1000 emplyees total
    emplyeeNum=1000
    # 9000 customer in the mall each day.
    customerNum=9000

    # ? length(filter((x)->x.isInfected, people))
    #Setting the 2D array for places
    places=[]
    for i in 1:98
        push!(places, [])
    end
    push!(overall,simulate(emplyeeNum,customerNum,(p-1)/10,[false,true,false])[2][30])
end

# %%
y = overall
x = map((i)->"$((i-1)*10)%",1:11)
plot(x, y, title = "Overall infection")
scatter!(x,y, label="point")
xlabel!("Percent of people following the interventions")
ylabel!("Overall infection")

# %% [markdown]
# # - Following intervention 2,3,4

# %%
overall = []
for p in 1:11
    #Simulation variables:
    # 500 emplyees total
    emplyeeNum=500
    # 4500 customer in the mall each day.
    customerNum=4500

    # ? length(filter((x)->x.isInfected, people))
    #Setting the 2D array for places
    places=[]
    for i in 1:98
        push!(places, [])
    end
    push!(overall,simulate(emplyeeNum,customerNum,(p-1)/10,[false,true,true])[2][30])
end

# %%
y = overall
x = map((i)->"$((i-1)*10)%",1:11)
plot(x, y, title = "Overall infection")
scatter!(x,y, label="point")
xlabel!("Percent of people following the interventions")
ylabel!("Overall infection")
